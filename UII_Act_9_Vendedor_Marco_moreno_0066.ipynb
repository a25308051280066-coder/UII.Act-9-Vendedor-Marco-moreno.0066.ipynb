# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280066-coder/UII.Act-9-Vendedor-Marco-moreno.0066.ipynb/blob/main/UII_Act_9_Vendedor_Marco_moreno_0066.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Marco Moreno NL= 16 Fecha 25/05/26

# %%
# Lista vacía
productos = []

while True:

    print("\n===== MENU VENDEDOR INTELIGENTE =====")
    print("1. Agregar producto")
    print("2. Ver productos")
    print("3. Buscar producto")
    print("4. Eliminar producto")
    print("5. Salir")

    opcion = input("Selecciona una opcion: ")

    if opcion == "1":

        producto = input("Ingresa el nombre del producto: ")
        productos.append(producto)

        print("Producto agregado correctamente")

    elif opcion == "2":

        if productos == []:
            print("La lista esta vacia")
        else:
            print("Productos registrados:")
            print(productos)

    elif opcion == "3":

        buscar = input("Ingresa el producto a buscar: ")

        if buscar in productos:
            print("El producto SI existe")
        else:
            print("El producto NO existe")

    elif opcion == "4":

        eliminar = input("Ingresa el producto a eliminar: ")

        if eliminar in productos:
            productos.remove(eliminar)
            print("Producto eliminado")
        else:
            print("Ese producto no existe")

    elif opcion == "5":

        print("Saliendo del sistema...")
        break

    else:

        print("Opcion incorrecta")
        print("Programa realizado por Marco Moreno NL=16")
# Out:
# ===== MENU VENDEDOR INTELIGENTE =====
# 1. Agregar producto
# 2. Ver productos
# 3. Buscar producto
# 4. Eliminar producto
# 5. Salir
# Selecciona una opcion: 1
# Ingresa el nombre del producto: MAGICFILE
# Producto agregado correctamente
#
# ===== MENU VENDEDOR INTELIGENTE =====
# 1. Agregar producto
# 2. Ver productos
# 3. Buscar producto
# 4. Eliminar producto
# 5. Salir
# Selecciona una opcion: 2
# Productos registrados:
# ['MAGICFILE']
#
# ===== MENU VENDEDOR INTELIGENTE =====
# 1. Agregar producto
# 2. Ver productos
# 3. Buscar producto
# 4. Eliminar producto
# 5. Salir
# Selecciona una opcion: 3
# Ingresa el producto a buscar: MAGICFILE
# El producto SI existe
#
# ===== MENU VENDEDOR INTELIGENTE =====
# 1. Agregar producto
# 2. Ver productos
# 3. Buscar producto
# 4. Eliminar producto
# 5. Salir
# Selecciona una opcion: 4
# Ingresa el producto a eliminar: MAGICFILE
# Producto eliminado
#
# ===== MENU VENDEDOR INTELIGENTE =====
# 1. Agregar producto
# 2. Ver productos
# ...

# %% [markdown]
# <img src="https://raw.githubusercontent.com/a25308051280066-coder/UII.Act-9-Vendedor-Marco-moreno.0066.ipynb/refs/heads/main/vendedor.png">
